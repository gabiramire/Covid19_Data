# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv(os.path.join('..','csv', 'worldometer_coronavirus_summary_data.csv'))
df
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia           147473
# 1                      Albania             Europe           133081
# 2                      Algeria             Africa           171392
# 3                      Andorra             Europe            14678
# 4                       Angola             Africa            42646
# ..                         ...                ...              ...
# 215  Wallis And Futuna Islands  Australia/Oceania              445
# 216             Western Sahara             Africa               10
# 217                      Yemen               Asia             7061
# 218                     Zambia             Africa           195816
# 219                   Zimbabwe             Africa           107490
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          6736.0          98073.0       42664.0               1124.0
# ...

# %%
df_quant = []
df_str = []
for i in df:
    if type(df[i][0]) is str:
        df_str.append(df[i])
    elif len(df[i].unique()) >= 10:
        df_quant.append(df[i])
print(df_quant)
# Out:
# [0      147473
# 1      133081
# 2      171392
# 3       14678
# 4       42646
#         ...
# 215       445
# 216        10
# 217      7061
# 218    195816
# 219    107490
# Name: total_confirmed, Length: 220, dtype: int64, 0      6736.0
# 1      2457.0
# 2      4254.0
# 3       128.0
# 4      1008.0
#         ...
# 215       7.0
# 216       1.0
# 217    1375.0
# 218    3389.0
# 219    3490.0
# Name: total_deaths, Length: 220, dtype: float64, 0       98073.0
# 1      130222.0
# 2      115276.0
# 3       14210.0
# 4       36708.0
#          ...
# 215       438.0
# 216         8.0
# 217      4185.0
# 218    187236.0
# 219     74562.0
# Name: total_recovered, Length: 220, dtype: float64, 0      42664.0
# 1        402.0
# 2      51862.0
# 3        340.0
# 4       4930.0
#         ...
# 215        0.0
# 216        1.0
# 217     1501.0
# 218     5191.0
# 219    29438.0
# Name: active_cases, Length: 220, dtype: float64, 0      1124.0
# 1         3.0
# 2        47.0
# 3         NaN
# ...
